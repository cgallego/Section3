# %%
from DeepLearnFuncs import *
import six.moves.cPickle as cPickle

import matplotlib.pyplot as plt
# %matplotlib inline  
plt.rcParams['figure.figsize'] = (16, 10)

# start by importing Deep Learning Funcs
funcs = DeepLearnFuncs()

pretraining_epochs = 100
pretrain_lr = 0.0095
finetune_lr = 0.025

training_epochs = 1000
batch_size = 1

output_folder = 'plots/SdA_plots'
corruption_levels=[0.1, 0.2, 0.3]

    
############
# train Stacked dAutoencoder                 
############
dfpredata, dfinedata = funcs.test_SdA(finetune_lr, pretraining_epochs, pretrain_lr, training_epochs, batch_size, corruption_levels, output_folder)
# Out:
# DEBUG: nvcc STDOUT mod.cu
#    Creating library E:/Users/DeepLearning/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_60_Stepping_3_GenuineIntel-2.7.11-64/tmppublgn/265abc51f7c376c224983485238ff1a5.lib and object E:/Users/DeepLearning/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_60_Stepping_3_GenuineIntel-2.7.11-64/tmppublgn/265abc51f7c376c224983485238ff1a5.exp
#
# Using gpu device 0: GeForce GTX 780 (CNMeM is enabled with initial size: 90.0% of memory, CuDNN 3007)
# E:\Users\DeepLearning\Anaconda2\Lib\site-packages\theano\tensor\signal\downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")
# ... loading data
#         lesion_id nmenh_dist nmenh_intenh
# count        8884       8884         8884
# unique        500          6            4
# top           576        N/A          N/A
# freq           25       4150         8182
# [(u'Ductal', 0), (u'Focal', 1), (u'Linear', 2), (u'N/A', 3), (u'Regional', 4), (u'Segmental', 5)]
# Removing incomplete patches...
# [505, 951, 1467, 1818, 2040, 3220, 3789, 4112, 4924, 5068, 6067, 8838]
# Number of patches: 5279 train, 1816 valid, 1777 test
# ... building the Stacked Autoenconder model
# ... getting the pretraining functions
# ... pre-training the model
# Pre-training layer 0, epoch 0, cost 506.913239
# Pre-training layer 0, epoch 1, cost 500.786926
# Pre-training layer 0, epoch 2, cost 498.557770
# Pre-training layer 0, epoch 3, cost 497.083252
# Pre-training layer 0, epoch 4, cost 495.922333
# Pre-training layer 0, epoch 5, cost 494.992981
# Pre-training layer 0, epoch 6, cost 494.265869
# Pre-training layer 0, epoch 7, cost 493.697021
# Pre-training layer 0, epoch 8, cost 493.276337
# Pre-training layer 0, epoch 9, cost 492.896423
# Pre-training layer 0, epoch 10, cost 492.621521
# Pre-training layer 0, epoch 11, cost 492.380768
# Pre-training layer 0, epoch 12, cost 492.184021
# Pre-training layer 0, epoch 13, cost 492.043365
# Pre-training layer 0, epoch 14, cost 491.913727
# Pre-training layer 0, epoch 15, cost 491.781769
# Pre-training layer 0, epoch 16, cost 491.696899
# Pre-training layer 0, epoch 17, cost 491.594818
# Pre-training layer 0, epoch 18, cost 491.500000
# Pre-training layer 0, epoch 19, cost 491.435272
# Pre-training layer 0, epoch 20, cost 491.384979
# Pre-training layer 0, epoch 21, cost 491.313080
# Pre-training layer 0, epoch 22, cost 491.256439
# Pre-training layer 0, epoch 23, cost 491.207428
# Pre-training layer 0, epoch 24, cost 491.190430
# Pre-training layer 0, epoch 25, cost 491.141602
# Pre-training layer 0, epoch 26, cost 491.100647
# Pre-training layer 0, epoch 27, cost 491.055206
# Pre-training layer 0, epoch 28, cost 491.021545
# Pre-training layer 0, epoch 29, cost 490.990875
# Pre-training layer 0, epoch 30, cost 490.957001
# Pre-training layer 0, epoch 31, cost 490.913208
# Pre-training layer 0, epoch 32, cost 490.874451
# Pre-training layer 0, epoch 33, cost 490.855743
# Pre-training layer 0, epoch 34, cost 490.821136
# Pre-training layer 0, epoch 35, cost 490.819580
# Pre-training layer 0, epoch 36, cost 490.747772
# Pre-training layer 0, epoch 37, cost 490.735840
# Pre-training layer 0, epoch 38, cost 490.713440
# Pre-training layer 0, epoch 39, cost 490.683594
# Pre-training layer 0, epoch 40, cost 490.657318
# Pre-training layer 0, epoch 41, cost 490.617767
# Pre-training layer 0, epoch 42, cost 490.601868
# Pre-training layer 0, epoch 43, cost 490.585327
# Pre-training layer 0, epoch 44, cost 490.525574
# Pre-training layer 0, epoch 45, cost 490.518951
# Pre-training layer 0, epoch 46, cost 490.505310
# Pre-training layer 0, epoch 47, cost 490.453827
# Pre-training layer 0, epoch 48, cost 490.452271
# Pre-training layer 0, epoch 49, cost 490.417328
# Pre-training layer 0, epoch 50, cost 490.392029
# Pre-training layer 0, epoch 51, cost 490.386108
# Pre-training layer 0, epoch 52, cost 490.355560
# Pre-training layer 0, epoch 53, cost 490.337952
# Pre-training layer 0, epoch 54, cost 490.314636
# Pre-training layer 0, epoch 55, cost 490.302246
# Pre-training layer 0, epoch 56, cost 490.263916
# Pre-training layer 0, epoch 57, cost 490.260223
# Pre-training layer 0, epoch 58, cost 490.223633
# Pre-training layer 0, epoch 59, cost 490.197113
# Pre-training layer 0, epoch 60, cost 490.174072
# Pre-training layer 0, epoch 61, cost 490.165833
# Pre-training layer 0, epoch 62, cost 490.158325
# Pre-training layer 0, epoch 63, cost 490.135254
# Pre-training layer 0, epoch 64, cost 490.111481
# Pre-training layer 0, epoch 65, cost 490.090271
# Pre-training layer 0, epoch 66, cost 490.070190
# Pre-training layer 0, epoch 67, cost 490.065247
# Pre-training layer 0, epoch 68, cost 490.045685
# Pre-training layer 0, epoch 69, cost 490.039246
# Pre-training layer 0, epoch 70, cost 490.015350
# Pre-training layer 0, epoch 71, cost 489.969940
# Pre-training layer 0, epoch 72, cost 489.976288
# Pre-training layer 0, epoch 73, cost 489.965424
# Pre-training layer 0, epoch 74, cost 489.929810
# Pre-training layer 0, epoch 75, cost 489.932129
# Pre-training layer 0, epoch 76, cost 489.897766
# Pre-training layer 0, epoch 77, cost 489.890503
# Pre-training layer 0, epoch 78, cost 489.882843
# Pre-training layer 0, epoch 79, cost 489.859528
# Pre-training layer 0, epoch 80, cost 489.836151
# Pre-training layer 0, epoch 81, cost 489.842255
# Pre-training layer 0, epoch 82, cost 489.817963
# Pre-training layer 0, epoch 83, cost 489.831787
# Pre-training layer 0, epoch 84, cost 489.808960
# Pre-training layer 0, epoch 85, cost 489.780060
# Pre-training layer 0, epoch 86, cost 489.782074
# Pre-training layer 0, epoch 87, cost 489.744568
# Pre-training layer 0, epoch 88, cost 489.737549
# Pre-training layer 0, epoch 89, cost 489.753510
# Pre-training layer 0, epoch 90, cost 489.706573
# Pre-training layer 0, epoch 91, cost 489.697845
# Pre-training layer 0, epoch 92, cost 489.699127
# Pre-training layer 0, epoch 93, cost 489.697021
# Pre-training layer 0, epoch 94, cost 489.687439
# Pre-training layer 0, epoch 95, cost 489.662140
# Pre-training layer 0, epoch 96, cost 489.655151
# Pre-training layer 0, epoch 97, cost 489.636292
# Pre-training layer 0, epoch 98, cost 489.626160
# Pre-training layer 0, epoch 99, cost 489.606049
# Pre-training layer 1, epoch 0, cost 247.869736
# Pre-training layer 1, epoch 1, cost 241.121918
# Pre-training layer 1, epoch 2, cost 239.357376
# Pre-training layer 1, epoch 3, cost 238.343246
# Pre-training layer 1, epoch 4, cost 237.652161
# Pre-training layer 1, epoch 5, cost 237.139496
# Pre-training layer 1, epoch 6, cost 236.726990
# Pre-training layer 1, epoch 7, cost 236.472443
# Pre-training layer 1, epoch 8, cost 236.211456
# Pre-training layer 1, epoch 9, cost 235.915283
# Pre-training layer 1, epoch 10, cost 235.808105
# Pre-training layer 1, epoch 11, cost 235.652069
# Pre-training layer 1, epoch 12, cost 235.458038
# Pre-training layer 1, epoch 13, cost 235.333633
# Pre-training layer 1, epoch 14, cost 235.243301
# Pre-training layer 1, epoch 15, cost 235.118515
# Pre-training layer 1, epoch 16, cost 235.022018
# Pre-training layer 1, epoch 17, cost 234.936066
# Pre-training layer 1, epoch 18, cost 234.866302
# Pre-training layer 1, epoch 19, cost 234.817337
# Pre-training layer 1, epoch 20, cost 234.733856
# Pre-training layer 1, epoch 21, cost 234.677872
# Pre-training layer 1, epoch 22, cost 234.647232
# Pre-training layer 1, epoch 23, cost 234.600876
# Pre-training layer 1, epoch 24, cost 234.519180
# Pre-training layer 1, epoch 25, cost 234.460434
# Pre-training layer 1, epoch 26, cost 234.459885
# Pre-training layer 1, epoch 27, cost 234.441559
# Pre-training layer 1, epoch 28, cost 234.411118
# Pre-training layer 1, epoch 29, cost 234.369385
# Pre-training layer 1, epoch 30, cost 234.309891
# Pre-training layer 1, epoch 31, cost 234.309677
# Pre-training layer 1, epoch 32, cost 234.282608
# Pre-training layer 1, epoch 33, cost 234.246964
# Pre-training layer 1, epoch 34, cost 234.222626
# Pre-training layer 1, epoch 35, cost 234.220352
# Pre-training layer 1, epoch 36, cost 234.151260
# Pre-training layer 1, epoch 37, cost 234.118652
# Pre-training layer 1, epoch 38, cost 234.128342
# Pre-training layer 1, epoch 39, cost 234.116302
# Pre-training layer 1, epoch 40, cost 234.076370
# Pre-training layer 1, epoch 41, cost 234.055481
# Pre-training layer 1, epoch 42, cost 234.031967
# Pre-training layer 1, epoch 43, cost 234.021210
# Pre-training layer 1, epoch 44, cost 234.000336
# Pre-training layer 1, epoch 45, cost 233.965683
# Pre-training layer 1, epoch 46, cost 234.010223
# Pre-training layer 1, epoch 47, cost 233.937790
# Pre-training layer 1, epoch 48, cost 233.920181
# Pre-training layer 1, epoch 49, cost 233.914276
# Pre-training layer 1, epoch 50, cost 233.904984
# Pre-training layer 1, epoch 51, cost 233.860764
# Pre-training layer 1, epoch 52, cost 233.886765
# Pre-training layer 1, epoch 53, cost 233.828796
# Pre-training layer 1, epoch 54, cost 233.846237
# Pre-training layer 1, epoch 55, cost 233.814758
# Pre-training layer 1, epoch 56, cost 233.817581
# Pre-training layer 1, epoch 57, cost 233.805435
# Pre-training layer 1, epoch 58, cost 233.763306
# Pre-training layer 1, epoch 59, cost 233.739532
# Pre-training layer 1, epoch 60, cost 233.767838
# Pre-training layer 1, epoch 61, cost 233.718109
# Pre-training layer 1, epoch 62, cost 233.706573
# Pre-training layer 1, epoch 63, cost 233.757904
# Pre-training layer 1, epoch 64, cost 233.685928
# Pre-training layer 1, epoch 65, cost 233.666840
# Pre-training layer 1, epoch 66, cost 233.687637
# Pre-training layer 1, epoch 67, cost 233.658081
# Pre-training layer 1, epoch 68, cost 233.684219
# Pre-training layer 1, epoch 69, cost 233.668030
# Pre-training layer 1, epoch 70, cost 233.663910
# Pre-training layer 1, epoch 71, cost 233.681244
# Pre-training layer 1, epoch 72, cost 233.641403
# Pre-training layer 1, epoch 73, cost 233.653931
# Pre-training layer 1, epoch 74, cost 233.592255
# Pre-training layer 1, epoch 75, cost 233.615479
# Pre-training layer 1, epoch 76, cost 233.615036
# Pre-training layer 1, epoch 77, cost 233.572266
# Pre-training layer 1, epoch 78, cost 233.567200
# Pre-training layer 1, epoch 79, cost 233.578751
# Pre-training layer 1, epoch 80, cost 233.531616
# Pre-training layer 1, epoch 81, cost 233.552994
# Pre-training layer 1, epoch 82, cost 233.512329
# Pre-training layer 1, epoch 83, cost 233.559006
# Pre-training layer 1, epoch 84, cost 233.509384
# Pre-training layer 1, epoch 85, cost 233.529266
# Pre-training layer 1, epoch 86, cost 233.527557
# Pre-training layer 1, epoch 87, cost 233.515350
# Pre-training layer 1, epoch 88, cost 233.509964
# Pre-training layer 1, epoch 89, cost 233.499817
# Pre-training layer 1, epoch 90, cost 233.523254
# Pre-training layer 1, epoch 91, cost 233.475250
# Pre-training layer 1, epoch 92, cost 233.497208
# Pre-training layer 1, epoch 93, cost 233.495956
# Pre-training layer 1, epoch 94, cost 233.506577
# Pre-training layer 1, epoch 95, cost 233.450684
# Pre-training layer 1, epoch 96, cost 233.474762
# Pre-training layer 1, epoch 97, cost 233.460083
# Pre-training layer 1, epoch 98, cost 233.439804
# Pre-training layer 1, epoch 99, cost 233.462967
# Pre-training layer 2, epoch 0, cost 110.544762
# Pre-training layer 2, epoch 1, cost 105.640839
# Pre-training layer 2, epoch 2, cost 104.606934
# Pre-training layer 2, epoch 3, cost 104.057846
# Pre-training layer 2, epoch 4, cost 103.729805
# Pre-training layer 2, epoch 5, cost 103.378838
# Pre-training layer 2, epoch 6, cost 103.212395
# Pre-training layer 2, epoch 7, cost 103.060783
# Pre-training layer 2, epoch 8, cost 102.902657
# Pre-training layer 2, epoch 9, cost 102.798340
# Pre-training layer 2, epoch 10, cost 102.707024
# Pre-training layer 2, epoch 11, cost 102.615219
# Pre-training layer 2, epoch 12, cost 102.531395
# Pre-training layer 2, epoch 13, cost 102.436539
# Pre-training layer 2, epoch 14, cost 102.412956
# Pre-training layer 2, epoch 15, cost 102.314903
# Pre-training layer 2, epoch 16, cost 102.292969
# Pre-training layer 2, epoch 17, cost 102.267166
# Pre-training layer 2, epoch 18, cost 102.174751
# Pre-training layer 2, epoch 19, cost 102.205978
# Pre-training layer 2, epoch 20, cost 102.138756
# Pre-training layer 2, epoch 21, cost 102.097488
# Pre-training layer 2, epoch 22, cost 102.059944
# Pre-training layer 2, epoch 23, cost 102.012077
# Pre-training layer 2, epoch 24, cost 101.982536
# Pre-training layer 2, epoch 25, cost 101.969505
# Pre-training layer 2, epoch 26, cost 101.949028
# Pre-training layer 2, epoch 27, cost 101.919304
# Pre-training layer 2, epoch 28, cost 101.930550
# Pre-training layer 2, epoch 29, cost 101.876358
# Pre-training layer 2, epoch 30, cost 101.855133
# Pre-training layer 2, epoch 31, cost 101.874229
# Pre-training layer 2, epoch 32, cost 101.800285
# Pre-training layer 2, epoch 33, cost 101.802498
# Pre-training layer 2, epoch 34, cost 101.751091
# Pre-training layer 2, epoch 35, cost 101.743904
# Pre-training layer 2, epoch 36, cost 101.748840
# Pre-training layer 2, epoch 37, cost 101.714600
# Pre-training layer 2, epoch 38, cost 101.728500
# Pre-training layer 2, epoch 39, cost 101.682823
# Pre-training layer 2, epoch 40, cost 101.701508
# Pre-training layer 2, epoch 41, cost 101.669235
# Pre-training layer 2, epoch 42, cost 101.655380
# Pre-training layer 2, epoch 43, cost 101.619995
# Pre-training layer 2, epoch 44, cost 101.619743
# Pre-training layer 2, epoch 45, cost 101.629120
# Pre-training layer 2, epoch 46, cost 101.619934
# Pre-training layer 2, epoch 47, cost 101.589409
# Pre-training layer 2, epoch 48, cost 101.570015
# Pre-training layer 2, epoch 49, cost 101.553360
# Pre-training layer 2, epoch 50, cost 101.586937
# Pre-training layer 2, epoch 51, cost 101.550339
# Pre-training layer 2, epoch 52, cost 101.562889
# Pre-training layer 2, epoch 53, cost 101.548729
# Pre-training layer 2, epoch 54, cost 101.515022
# Pre-training layer 2, epoch 55, cost 101.542671
# Pre-training layer 2, epoch 56, cost 101.542458
# Pre-training layer 2, epoch 57, cost 101.527802
# Pre-training layer 2, epoch 58, cost 101.510712
# Pre-training layer 2, epoch 59, cost 101.491005
# Pre-training layer 2, epoch 60, cost 101.489204
# Pre-training layer 2, epoch 61, cost 101.484940
# Pre-training layer 2, epoch 62, cost 101.452278
# Pre-training layer 2, epoch 63, cost 101.460953
# Pre-training layer 2, epoch 64, cost 101.482971
# Pre-training layer 2, epoch 65, cost 101.443642
# Pre-training layer 2, epoch 66, cost 101.481659
# Pre-training layer 2, epoch 67, cost 101.442902
# Pre-training layer 2, epoch 68, cost 101.465302
# Pre-training layer 2, epoch 69, cost 101.430550
# Pre-training layer 2, epoch 70, cost 101.397400
# Pre-training layer 2, epoch 71, cost 101.409195
# Pre-training layer 2, epoch 72, cost 101.398232
# Pre-training layer 2, epoch 73, cost 101.413383
# Pre-training layer 2, epoch 74, cost 101.389397
# Pre-training layer 2, epoch 75, cost 101.361954
# Pre-training layer 2, epoch 76, cost 101.370667
# Pre-training layer 2, epoch 77, cost 101.387619
# Pre-training layer 2, epoch 78, cost 101.381607
# Pre-training layer 2, epoch 79, cost 101.381561
# Pre-training layer 2, epoch 80, cost 101.343887
# Pre-training layer 2, epoch 81, cost 101.370049
# Pre-training layer 2, epoch 82, cost 101.353714
# Pre-training layer 2, epoch 83, cost 101.309731
# Pre-training layer 2, epoch 84, cost 101.323616
# Pre-training layer 2, epoch 85, cost 101.330559
# Pre-training layer 2, epoch 86, cost 101.352982
# Pre-training layer 2, epoch 87, cost 101.345757
# Pre-training layer 2, epoch 88, cost 101.357727
# Pre-training layer 2, epoch 89, cost 101.315353
# Pre-training layer 2, epoch 90, cost 101.347328
# Pre-training layer 2, epoch 91, cost 101.320251
# Pre-training layer 2, epoch 92, cost 101.297523
# Pre-training layer 2, epoch 93, cost 101.325401
# Pre-training layer 2, epoch 94, cost 101.318855
# Pre-training layer 2, epoch 95, cost 101.294518
# Pre-training layer 2, epoch 96, cost 101.306725
# Pre-training layer 2, epoch 97, cost 101.265945
# Pre-training layer 2, epoch 98, cost 101.292809
# Pre-training layer 2, epoch 99, cost 101.301865
# The pretraining code for file DeepLearnFuncs.pyc ran for 96.55m
# ... getting the finetuning functions
# ... finetunning the Stacked model
# epoch 1, minibatch 5279/5279, validation error 76.211454 %
#      epoch 1, minibatch 5279/5279, test error of best model 67.698368 %
# epoch 2, minibatch 5279/5279, validation error 76.211454 %
# epoch 3, minibatch 5279/5279, validation error 76.211454 %
# epoch 4, minibatch 5279/5279, validation error 76.211454 %
# epoch 5, minibatch 5279/5279, validation error 76.211454 %
# epoch 6, minibatch 5279/5279, validation error 76.211454 %
# epoch 7, minibatch 5279/5279, validation error 76.211454 %
# epoch 8, minibatch 5279/5279, validation error 76.211454 %
# epoch 9, minibatch 5279/5279, validation error 76.211454 %
# epoch 10, minibatch 5279/5279, validation error 76.211454 %
# epoch 11, minibatch 5279/5279, validation error 76.211454 %
# epoch 12, minibatch 5279/5279, validation error 76.156388 %
#      epoch 12, minibatch 5279/5279, test error of best model 67.698368 %
# epoch 13, minibatch 5279/5279, validation error 76.156388 %
# epoch 14, minibatch 5279/5279, validation error 76.156388 %
# epoch 15, minibatch 5279/5279, validation error 76.046256 %
#      epoch 15, minibatch 5279/5279, test error of best model 67.698368 %
# epoch 16, minibatch 5279/5279, validation error 75.991189 %
#      epoch 16, minibatch 5279/5279, test error of best model 67.642093 %
# epoch 17, minibatch 5279/5279, validation error 75.936123 %
#      epoch 17, minibatch 5279/5279, test error of best model 67.698368 %
# epoch 18, minibatch 5279/5279, validation error 75.991189 %
# epoch 19, minibatch 5279/5279, validation error 75.991189 %
# epoch 20, minibatch 5279/5279, validation error 75.881057 %
#      epoch 20, minibatch 5279/5279, test error of best model 67.754643 %
# epoch 21, minibatch 5279/5279, validation error 75.770925 %
#      epoch 21, minibatch 5279/5279, test error of best model 67.754643 %
# epoch 22, minibatch 5279/5279, validation error 75.495595 %
#      epoch 22, minibatch 5279/5279, test error of best model 67.810917 %
# epoch 23, minibatch 5279/5279, validation error 75.660793 %
# epoch 24, minibatch 5279/5279, validation error 75.770925 %
# epoch 25, minibatch 5279/5279, validation error 75.936123 %
# epoch 26, minibatch 5279/5279, validation error 75.991189 %
# epoch 27, minibatch 5279/5279, validation error 75.550661 %
# epoch 28, minibatch 5279/5279, validation error 75.660793 %
# epoch 29, minibatch 5279/5279, validation error 75.660793 %
# epoch 30, minibatch 5279/5279, validation error 75.991189 %
# epoch 31, minibatch 5279/5279, validation error 75.991189 %
# epoch 32, minibatch 5279/5279, validation error 75.770925 %
# epoch 33, minibatch 5279/5279, validation error 75.550661 %
# epoch 34, minibatch 5279/5279, validation error 75.220264 %
#      epoch 34, minibatch 5279/5279, test error of best model 68.767586 %
# epoch 35, minibatch 5279/5279, validation error 74.834802 %
#      epoch 35, minibatch 5279/5279, test error of best model 69.161508 %
# epoch 36, minibatch 5279/5279, validation error 75.660793 %
# epoch 37, minibatch 5279/5279, validation error 75.220264 %
# epoch 38, minibatch 5279/5279, validation error 75.220264 %
# epoch 39, minibatch 5279/5279, validation error 75.330396 %
# epoch 40, minibatch 5279/5279, validation error 75.000000 %
# epoch 41, minibatch 5279/5279, validation error 75.660793 %
# epoch 42, minibatch 5279/5279, validation error 75.110132 %
# epoch 43, minibatch 5279/5279, validation error 75.660793 %
# epoch 44, minibatch 5279/5279, validation error 75.770925 %
# epoch 45, minibatch 5279/5279, validation error 75.055066 %
# epoch 46, minibatch 5279/5279, validation error 75.440529 %
# epoch 47, minibatch 5279/5279, validation error 75.000000 %
# epoch 48, minibatch 5279/5279, validation error 75.550661 %
# epoch 49, minibatch 5279/5279, validation error 75.275330 %
# epoch 50, minibatch 5279/5279, validation error 75.605727 %
# epoch 51, minibatch 5279/5279, validation error 74.284141 %
#      epoch 51, minibatch 5279/5279, test error of best model 70.680923 %
# epoch 52, minibatch 5279/5279, validation error 74.008811 %
#      epoch 52, minibatch 5279/5279, test error of best model 68.880135 %
# epoch 53, minibatch 5279/5279, validation error 73.458150 %
#      epoch 53, minibatch 5279/5279, test error of best model 68.148565 %
# epoch 54, minibatch 5279/5279, validation error 74.339207 %
# epoch 55, minibatch 5279/5279, validation error 74.394273 %
# epoch 56, minibatch 5279/5279, validation error 74.118943 %
# epoch 57, minibatch 5279/5279, validation error 73.513216 %
# epoch 58, minibatch 5279/5279, validation error 73.678414 %
# epoch 59, minibatch 5279/5279, validation error 73.237885 %
#      epoch 59, minibatch 5279/5279, test error of best model 70.399550 %
# epoch 60, minibatch 5279/5279, validation error 72.632159 %
#      epoch 60, minibatch 5279/5279, test error of best model 68.655037 %
# epoch 61, minibatch 5279/5279, validation error 72.962555 %
# epoch 62, minibatch 5279/5279, validation error 71.916300 %
#      epoch 62, minibatch 5279/5279, test error of best model 69.442881 %
# epoch 63, minibatch 5279/5279, validation error 72.026432 %
# epoch 64, minibatch 5279/5279, validation error 70.759912 %
#      epoch 64, minibatch 5279/5279, test error of best model 68.148565 %
# epoch 65, minibatch 5279/5279, validation error 72.081498 %
# epoch 66, minibatch 5279/5279, validation error 72.411894 %
# epoch 67, minibatch 5279/5279, validation error 71.090308 %
# epoch 68, minibatch 5279/5279, validation error 72.246696 %
# epoch 69, minibatch 5279/5279, validation error 71.861233 %
# epoch 70, minibatch 5279/5279, validation error 72.907489 %
# epoch 71, minibatch 5279/5279, validation error 70.814978 %
# epoch 72, minibatch 5279/5279, validation error 71.751101 %
# epoch 73, minibatch 5279/5279, validation error 71.200441 %
# epoch 74, minibatch 5279/5279, validation error 71.365639 %
# epoch 75, minibatch 5279/5279, validation error 71.035242 %
# epoch 76, minibatch 5279/5279, validation error 71.806167 %
# epoch 77, minibatch 5279/5279, validation error 73.348018 %
# epoch 78, minibatch 5279/5279, validation error 72.081498 %
# epoch 79, minibatch 5279/5279, validation error 70.209251 %
#      epoch 79, minibatch 5279/5279, test error of best model 68.767586 %
# epoch 80, minibatch 5279/5279, validation error 70.264317 %
# epoch 81, minibatch 5279/5279, validation error 69.933921 %
#      epoch 81, minibatch 5279/5279, test error of best model 69.442881 %
# epoch 82, minibatch 5279/5279, validation error 72.136564 %
# epoch 83, minibatch 5279/5279, validation error 71.365639 %
# epoch 84, minibatch 5279/5279, validation error 69.768722 %
#      epoch 84, minibatch 5279/5279, test error of best model 67.585819 %
# epoch 85, minibatch 5279/5279, validation error 68.722467 %
#      epoch 85, minibatch 5279/5279, test error of best model 65.897580 %
# epoch 86, minibatch 5279/5279, validation error 68.392070 %
#      epoch 86, minibatch 5279/5279, test error of best model 67.867192 %
# epoch 87, minibatch 5279/5279, validation error 68.832599 %
# epoch 88, minibatch 5279/5279, validation error 70.649780 %
# epoch 89, minibatch 5279/5279, validation error 71.420705 %
# epoch 90, minibatch 5279/5279, validation error 68.997797 %
# epoch 91, minibatch 5279/5279, validation error 70.209251 %
# epoch 92, minibatch 5279/5279, validation error 69.988987 %
# epoch 93, minibatch 5279/5279, validation error 69.438326 %
# epoch 94, minibatch 5279/5279, validation error 71.310573 %
# epoch 95, minibatch 5279/5279, validation error 70.154185 %
# epoch 96, minibatch 5279/5279, validation error 69.107930 %
# epoch 97, minibatch 5279/5279, validation error 69.933921 %
# epoch 98, minibatch 5279/5279, validation error 69.878855 %
# epoch 99, minibatch 5279/5279, validation error 72.356828 %
# epoch 100, minibatch 5279/5279, validation error 67.621145 %
#      epoch 100, minibatch 5279/5279, test error of best model 67.304446 %
# epoch 101, minibatch 5279/5279, validation error 71.640969 %
# epoch 102, minibatch 5279/5279, validation error 70.539648 %
# epoch 103, minibatch 5279/5279, validation error 71.585903 %
# epoch 104, minibatch 5279/5279, validation error 72.301762 %
# epoch 105, minibatch 5279/5279, validation error 70.980176 %
# epoch 106, minibatch 5279/5279, validation error 71.585903 %
# epoch 107, minibatch 5279/5279, validation error 69.878855 %
# epoch 108, minibatch 5279/5279, validation error 68.997797 %
# epoch 109, minibatch 5279/5279, validation error 71.530837 %
# epoch 110, minibatch 5279/5279, validation error 70.484581 %
# epoch 111, minibatch 5279/5279, validation error 71.696035 %
# epoch 112, minibatch 5279/5279, validation error 70.044053 %
# epoch 113, minibatch 5279/5279, validation error 68.887665 %
# epoch 114, minibatch 5279/5279, validation error 69.823789 %
# epoch 115, minibatch 5279/5279, validation error 70.925110 %
# epoch 116, minibatch 5279/5279, validation error 66.189427 %
#      epoch 116, minibatch 5279/5279, test error of best model 64.884637 %
# epoch 117, minibatch 5279/5279, validation error 68.557269 %
# epoch 118, minibatch 5279/5279, validation error 70.154185 %
# epoch 119, minibatch 5279/5279, validation error 69.218062 %
# epoch 120, minibatch 5279/5279, validation error 67.621145 %
# epoch 121, minibatch 5279/5279, validation error 68.722467 %
# epoch 122, minibatch 5279/5279, validation error 66.960352 %
# epoch 123, minibatch 5279/5279, validation error 67.290749 %
# epoch 124, minibatch 5279/5279, validation error 68.502203 %
# epoch 125, minibatch 5279/5279, validation error 66.189427 %
# epoch 126, minibatch 5279/5279, validation error 66.189427 %
# epoch 127, minibatch 5279/5279, validation error 64.812775 %
#      epoch 127, minibatch 5279/5279, test error of best model 63.252673 %
# epoch 128, minibatch 5279/5279, validation error 67.621145 %
# epoch 129, minibatch 5279/5279, validation error 69.162996 %
# epoch 130, minibatch 5279/5279, validation error 66.409692 %
# epoch 131, minibatch 5279/5279, validation error 66.299559 %
# epoch 132, minibatch 5279/5279, validation error 68.116740 %
# epoch 133, minibatch 5279/5279, validation error 68.226872 %
# epoch 134, minibatch 5279/5279, validation error 67.731278 %
# epoch 135, minibatch 5279/5279, validation error 68.997797 %
# epoch 136, minibatch 5279/5279, validation error 65.969163 %
# epoch 137, minibatch 5279/5279, validation error 66.519824 %
# epoch 138, minibatch 5279/5279, validation error 67.290749 %
# epoch 139, minibatch 5279/5279, validation error 68.612335 %
# epoch 140, minibatch 5279/5279, validation error 68.722467 %
# epoch 141, minibatch 5279/5279, validation error 64.592511 %
#      epoch 141, minibatch 5279/5279, test error of best model 63.477772 %
# epoch 142, minibatch 5279/5279, validation error 65.693833 %
# epoch 143, minibatch 5279/5279, validation error 70.099119 %
# epoch 144, minibatch 5279/5279, validation error 66.795154 %
# epoch 145, minibatch 5279/5279, validation error 65.528634 %
# epoch 146, minibatch 5279/5279, validation error 66.189427 %
# epoch 147, minibatch 5279/5279, validation error 65.143172 %
# epoch 148, minibatch 5279/5279, validation error 64.757709 %
# epoch 149, minibatch 5279/5279, validation error 66.189427 %
# epoch 150, minibatch 5279/5279, validation error 65.418502 %
# epoch 151, minibatch 5279/5279, validation error 66.740088 %
# epoch 152, minibatch 5279/5279, validation error 63.766520 %
#      epoch 152, minibatch 5279/5279, test error of best model 62.521103 %
# epoch 153, minibatch 5279/5279, validation error 66.740088 %
# epoch 154, minibatch 5279/5279, validation error 66.850220 %
# epoch 155, minibatch 5279/5279, validation error 66.905286 %
# epoch 156, minibatch 5279/5279, validation error 67.400881 %
# epoch 157, minibatch 5279/5279, validation error 66.299559 %
# epoch 158, minibatch 5279/5279, validation error 66.685022 %
# epoch 159, minibatch 5279/5279, validation error 68.061674 %
# epoch 160, minibatch 5279/5279, validation error 65.528634 %
# epoch 161, minibatch 5279/5279, validation error 68.392070 %
# epoch 162, minibatch 5279/5279, validation error 64.592511 %
# epoch 163, minibatch 5279/5279, validation error 67.400881 %
# epoch 164, minibatch 5279/5279, validation error 69.328194 %
# epoch 165, minibatch 5279/5279, validation error 65.693833 %
# epoch 166, minibatch 5279/5279, validation error 68.502203 %
# epoch 167, minibatch 5279/5279, validation error 66.629956 %
# epoch 168, minibatch 5279/5279, validation error 65.914097 %
# epoch 169, minibatch 5279/5279, validation error 61.453744 %
#      epoch 169, minibatch 5279/5279, test error of best model 61.114237 %
# epoch 170, minibatch 5279/5279, validation error 65.473568 %
# epoch 171, minibatch 5279/5279, validation error 66.519824 %
# epoch 172, minibatch 5279/5279, validation error 65.308370 %
# epoch 173, minibatch 5279/5279, validation error 65.693833 %
# epoch 174, minibatch 5279/5279, validation error 68.392070 %
# epoch 175, minibatch 5279/5279, validation error 67.235683 %
# epoch 176, minibatch 5279/5279, validation error 62.995595 %
# epoch 177, minibatch 5279/5279, validation error 67.125551 %
# epoch 178, minibatch 5279/5279, validation error 63.876652 %
# epoch 179, minibatch 5279/5279, validation error 64.922907 %
# epoch 180, minibatch 5279/5279, validation error 68.612335 %
# epoch 181, minibatch 5279/5279, validation error 70.429515 %
# epoch 182, minibatch 5279/5279, validation error 66.189427 %
# epoch 183, minibatch 5279/5279, validation error 65.914097 %
# epoch 184, minibatch 5279/5279, validation error 65.418502 %
# epoch 185, minibatch 5279/5279, validation error 67.125551 %
# epoch 186, minibatch 5279/5279, validation error 63.821586 %
# epoch 187, minibatch 5279/5279, validation error 65.748899 %
# epoch 188, minibatch 5279/5279, validation error 63.601322 %
# epoch 189, minibatch 5279/5279, validation error 66.244493 %
# epoch 190, minibatch 5279/5279, validation error 67.235683 %
# epoch 191, minibatch 5279/5279, validation error 64.537445 %
# epoch 192, minibatch 5279/5279, validation error 70.099119 %
# epoch 193, minibatch 5279/5279, validation error 68.226872 %
# epoch 194, minibatch 5279/5279, validation error 66.244493 %
# epoch 195, minibatch 5279/5279, validation error 67.125551 %
# epoch 196, minibatch 5279/5279, validation error 67.786344 %
# epoch 197, minibatch 5279/5279, validation error 69.823789 %
# epoch 198, minibatch 5279/5279, validation error 68.997797 %
# epoch 199, minibatch 5279/5279, validation error 65.859031 %
# epoch 200, minibatch 5279/5279, validation error 68.447137 %
# epoch 201, minibatch 5279/5279, validation error 65.528634 %
# epoch 202, minibatch 5279/5279, validation error 67.731278 %
# epoch 203, minibatch 5279/5279, validation error 64.151982 %
# epoch 204, minibatch 5279/5279, validation error 68.171806 %
# epoch 205, minibatch 5279/5279, validation error 63.381057 %
# epoch 206, minibatch 5279/5279, validation error 65.253304 %
# epoch 207, minibatch 5279/5279, validation error 63.711454 %
# epoch 208, minibatch 5279/5279, validation error 63.711454 %
# epoch 209, minibatch 5279/5279, validation error 64.702643 %
# epoch 210, minibatch 5279/5279, validation error 63.931718 %
# epoch 211, minibatch 5279/5279, validation error 65.418502 %
# epoch 212, minibatch 5279/5279, validation error 70.980176 %
# epoch 213, minibatch 5279/5279, validation error 63.160793 %
# epoch 214, minibatch 5279/5279, validation error 65.583700 %
# epoch 215, minibatch 5279/5279, validation error 65.418502 %
# epoch 216, minibatch 5279/5279, validation error 69.218062 %
# epoch 217, minibatch 5279/5279, validation error 62.169604 %
# epoch 218, minibatch 5279/5279, validation error 64.151982 %
# epoch 219, minibatch 5279/5279, validation error 64.757709 %
# epoch 220, minibatch 5279/5279, validation error 67.731278 %
# epoch 221, minibatch 5279/5279, validation error 68.337004 %
# epoch 222, minibatch 5279/5279, validation error 67.566079 %
# epoch 223, minibatch 5279/5279, validation error 64.096916 %
# epoch 224, minibatch 5279/5279, validation error 65.088106 %
# epoch 225, minibatch 5279/5279, validation error 65.748899 %
# epoch 226, minibatch 5279/5279, validation error 64.372247 %
# epoch 227, minibatch 5279/5279, validation error 64.537445 %
# epoch 228, minibatch 5279/5279, validation error 67.180617 %
# epoch 229, minibatch 5279/5279, validation error 63.766520 %
# epoch 230, minibatch 5279/5279, validation error 65.528634 %
# epoch 231, minibatch 5279/5279, validation error 67.511013 %
# epoch 232, minibatch 5279/5279, validation error 67.290749 %
# epoch 233, minibatch 5279/5279, validation error 68.612335 %
# epoch 234, minibatch 5279/5279, validation error 63.270925 %
# epoch 235, minibatch 5279/5279, validation error 65.693833 %
# epoch 236, minibatch 5279/5279, validation error 68.116740 %
# epoch 237, minibatch 5279/5279, validation error 66.960352 %
# epoch 238, minibatch 5279/5279, validation error 65.198238 %
# epoch 239, minibatch 5279/5279, validation error 63.986784 %
# epoch 240, minibatch 5279/5279, validation error 65.693833 %
# epoch 241, minibatch 5279/5279, validation error 63.656388 %
# epoch 242, minibatch 5279/5279, validation error 67.621145 %
# epoch 243, minibatch 5279/5279, validation error 63.656388 %
# epoch 244, minibatch 5279/5279, validation error 65.198238 %
# epoch 245, minibatch 5279/5279, validation error 65.143172 %
# epoch 246, minibatch 5279/5279, validation error 63.766520 %
# epoch 247, minibatch 5279/5279, validation error 66.244493 %
# epoch 248, minibatch 5279/5279, validation error 66.905286 %
# epoch 249, minibatch 5279/5279, validation error 64.482379 %
# epoch 250, minibatch 5279/5279, validation error 64.867841 %
# epoch 251, minibatch 5279/5279, validation error 68.667401 %
# epoch 252, minibatch 5279/5279, validation error 66.409692 %
# epoch 253, minibatch 5279/5279, validation error 65.418502 %
# epoch 254, minibatch 5279/5279, validation error 69.438326 %
# epoch 255, minibatch 5279/5279, validation error 64.757709 %
# epoch 256, minibatch 5279/5279, validation error 65.528634 %
# epoch 257, minibatch 5279/5279, validation error 65.748899 %
# epoch 258, minibatch 5279/5279, validation error 67.951542 %
# epoch 259, minibatch 5279/5279, validation error 66.629956 %
# epoch 260, minibatch 5279/5279, validation error 63.270925 %
# epoch 261, minibatch 5279/5279, validation error 66.629956 %
# epoch 262, minibatch 5279/5279, validation error 65.363436 %
# epoch 263, minibatch 5279/5279, validation error 64.151982 %
# epoch 264, minibatch 5279/5279, validation error 64.317181 %
# epoch 265, minibatch 5279/5279, validation error 66.024229 %
# epoch 266, minibatch 5279/5279, validation error 62.995595 %
# epoch 267, minibatch 5279/5279, validation error 68.171806 %
# epoch 268, minibatch 5279/5279, validation error 67.455947 %
# epoch 269, minibatch 5279/5279, validation error 66.905286 %
# epoch 270, minibatch 5279/5279, validation error 68.061674 %
# epoch 271, minibatch 5279/5279, validation error 66.960352 %
# epoch 272, minibatch 5279/5279, validation error 65.638767 %
# epoch 273, minibatch 5279/5279, validation error 65.583700 %
# epoch 274, minibatch 5279/5279, validation error 64.647577 %
# epoch 275, minibatch 5279/5279, validation error 64.977974 %
# epoch 276, minibatch 5279/5279, validation error 63.601322 %
# epoch 277, minibatch 5279/5279, validation error 64.647577 %
# epoch 278, minibatch 5279/5279, validation error 66.354626 %
# epoch 279, minibatch 5279/5279, validation error 65.803965 %
# epoch 280, minibatch 5279/5279, validation error 65.253304 %
# epoch 281, minibatch 5279/5279, validation error 64.812775 %
# epoch 282, minibatch 5279/5279, validation error 66.795154 %
# epoch 283, minibatch 5279/5279, validation error 67.235683 %
# epoch 284, minibatch 5279/5279, validation error 64.427313 %
# epoch 285, minibatch 5279/5279, validation error 64.262115 %
# epoch 286, minibatch 5279/5279, validation error 64.317181 %
# epoch 287, minibatch 5279/5279, validation error 66.189427 %
# epoch 288, minibatch 5279/5279, validation error 63.986784 %
# epoch 289, minibatch 5279/5279, validation error 62.995595 %
# epoch 290, minibatch 5279/5279, validation error 64.922907 %
# epoch 291, minibatch 5279/5279, validation error 64.922907 %
# epoch 292, minibatch 5279/5279, validation error 64.702643 %
# epoch 293, minibatch 5279/5279, validation error 65.308370 %
# epoch 294, minibatch 5279/5279, validation error 66.574890 %
# epoch 295, minibatch 5279/5279, validation error 66.134361 %
# epoch 296, minibatch 5279/5279, validation error 65.198238 %
# epoch 297, minibatch 5279/5279, validation error 64.647577 %
# epoch 298, minibatch 5279/5279, validation error 64.977974 %
# epoch 299, minibatch 5279/5279, validation error 65.088106 %
# epoch 300, minibatch 5279/5279, validation error 65.143172 %
# epoch 301, minibatch 5279/5279, validation error 63.105727 %
# epoch 302, minibatch 5279/5279, validation error 67.400881 %
# epoch 303, minibatch 5279/5279, validation error 63.601322 %
# epoch 304, minibatch 5279/5279, validation error 64.537445 %
# epoch 305, minibatch 5279/5279, validation error 63.821586 %
# epoch 306, minibatch 5279/5279, validation error 64.812775 %
# epoch 307, minibatch 5279/5279, validation error 62.940529 %
# epoch 308, minibatch 5279/5279, validation error 65.638767 %
# epoch 309, minibatch 5279/5279, validation error 63.436123 %
# epoch 310, minibatch 5279/5279, validation error 63.436123 %
# epoch 311, minibatch 5279/5279, validation error 64.537445 %
# epoch 312, minibatch 5279/5279, validation error 64.372247 %
# epoch 313, minibatch 5279/5279, validation error 64.041850 %
# epoch 314, minibatch 5279/5279, validation error 62.995595 %
# epoch 315, minibatch 5279/5279, validation error 65.969163 %
# epoch 316, minibatch 5279/5279, validation error 64.977974 %
# epoch 317, minibatch 5279/5279, validation error 65.914097 %
# epoch 318, minibatch 5279/5279, validation error 64.867841 %
# epoch 319, minibatch 5279/5279, validation error 62.940529 %
# epoch 320, minibatch 5279/5279, validation error 64.647577 %
# epoch 321, minibatch 5279/5279, validation error 63.986784 %
# epoch 322, minibatch 5279/5279, validation error 65.528634 %
# epoch 323, minibatch 5279/5279, validation error 65.693833 %
# epoch 324, minibatch 5279/5279, validation error 66.629956 %
# epoch 325, minibatch 5279/5279, validation error 65.748899 %
# epoch 326, minibatch 5279/5279, validation error 64.757709 %
# epoch 327, minibatch 5279/5279, validation error 65.088106 %
# epoch 328, minibatch 5279/5279, validation error 68.116740 %
# epoch 329, minibatch 5279/5279, validation error 65.473568 %
# epoch 330, minibatch 5279/5279, validation error 62.444934 %
# epoch 331, minibatch 5279/5279, validation error 65.198238 %
# epoch 332, minibatch 5279/5279, validation error 64.702643 %
# epoch 333, minibatch 5279/5279, validation error 63.986784 %
# epoch 334, minibatch 5279/5279, validation error 64.647577 %
# epoch 335, minibatch 5279/5279, validation error 64.317181 %
# epoch 336, minibatch 5279/5279, validation error 64.151982 %
# epoch 337, minibatch 5279/5279, validation error 66.850220 %
# Optimization complete with best validation score of 61.453744, on iteration 892151, with test performance 61.114237
# The training code for file DeepLearnFuncs.pyc ran for 35.54m

# %%
############
### plotting or cost
### the cost we minimize during training is the negative log likelihood of
############
plt.figure()
sns.lmplot('iter', 'LL_iter', data=dfpredata, hue='layer', fit_reg=False)
plt.xlabel('epoch', fontsize=14)
plt.ylabel('dA Cost', fontsize=14)
plt.title('Pretraining Stacked dAutoencoder learn_rate = '+str(pretrain_lr)+' pretrain_epochs = '+str(pretraining_epochs), fontsize=14)

# %%
############
### plotting likelihood or cost FIne tunning
### the cost we minimize during training is the negative log likelihood of
############
x = dfinedata['iter'].values
y = dfinedata['LL_iter'].values
plt.figure()
plt.plot(x, y, 'bo--')
plt.xlabel('iterations', fontsize=14)
plt.ylabel('negative log likelihood', fontsize=14)
plt.title('Fine Tunning: finetune_lr = '+str(finetune_lr)+' batch_size = '+str(batch_size), fontsize=14)

x = dfinedata['iter'].values
y = dfinedata['loss'].values
plt.figure()
plt.plot(x, y, 'bo--')
plt.xlabel('iterations')
plt.ylabel('Validation 0-1-loss %')
plt.title('Fine Tunning: finetune_lr = '+str(finetune_lr)+' batch_size = '+str(batch_size), fontsize=14)
