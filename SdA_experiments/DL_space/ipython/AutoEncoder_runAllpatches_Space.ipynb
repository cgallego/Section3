# %%
from DeepLearnFuncs import *
import six.moves.cPickle as cPickle

import matplotlib.pyplot as plt
# %matplotlib inline  
plt.rcParams['figure.figsize'] = (16, 10)
# Out:
# DEBUG: nvcc STDOUT mod.cu
#    Creating library E:/Users/DeepLearning/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_60_Stepping_3_GenuineIntel-2.7.11-64/tmpkgefjm/265abc51f7c376c224983485238ff1a5.lib and object E:/Users/DeepLearning/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_60_Stepping_3_GenuineIntel-2.7.11-64/tmpkgefjm/265abc51f7c376c224983485238ff1a5.exp
#
# Using gpu device 0: GeForce GTX 780 (CNMeM is enabled with initial size: 90.0% of memory, CuDNN 3007)
# E:\Users\DeepLearning\Anaconda2\Lib\site-packages\theano\tensor\signal\downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
# start by importing Deep Learning Funcs
funcs = DeepLearnFuncs()

learning_rate=0.0095
training_epochs=200
corruptionL=0.10
batch_size=2
output_folder='plots/dA_plots'

############
# train dAutoencoder                 
############
dfLLdata = funcs.test_dA(learning_rate, training_epochs, corruptionL, batch_size, output_folder)
# Out:
# ... loading data
#         lesion_id nmenh_dist nmenh_intenh
# count        8884       8884         8884
# unique        500          6            4
# top           576        N/A          N/A
# freq           25       4150         8182
# [(u'Ductal', 0), (u'Focal', 1), (u'Linear', 2), (u'N/A', 3), (u'Regional', 4), (u'Segmental', 5)]
# Removing incomplete patches...
# [505, 951, 1467, 1818, 2040, 3220, 3789, 4112, 4924, 5068, 6067, 8838]
# Number of patches: 5373 train, 1776 valid, 1723 test
# ('Training epoch 0, cost ', 530.66376)
# ('Training epoch 1, cost ', 513.9671)
# ('Training epoch 2, cost ', 508.29556)
# ('Training epoch 3, cost ', 505.26294)
# ('Training epoch 4, cost ', 503.36578)
# ('Training epoch 5, cost ', 502.09549)
# ('Training epoch 6, cost ', 501.21332)
# ('Training epoch 7, cost ', 500.56116)
# ('Training epoch 8, cost ', 500.05499)
# ('Training epoch 9, cost ', 499.64874)
# ('Training epoch 10, cost ', 499.30862)
# ('Training epoch 11, cost ', 499.00674)
# ('Training epoch 12, cost ', 498.72192)
# ('Training epoch 13, cost ', 498.52615)
# ('Training epoch 14, cost ', 498.35248)
# ('Training epoch 15, cost ', 498.20682)
# ('Training epoch 16, cost ', 498.06943)
# ('Training epoch 17, cost ', 497.94547)
# ('Training epoch 18, cost ', 497.84146)
# ('Training epoch 19, cost ', 497.73468)
# ('Training epoch 20, cost ', 497.64981)
# ('Training epoch 21, cost ', 497.53128)
# ('Training epoch 22, cost ', 497.39874)
# ('Training epoch 23, cost ', 497.2717)
# ('Training epoch 24, cost ', 497.15283)
# ('Training epoch 25, cost ', 497.05118)
# ('Training epoch 26, cost ', 496.95029)
# ('Training epoch 27, cost ', 496.88544)
# ('Training epoch 28, cost ', 496.79407)
# ('Training epoch 29, cost ', 496.72125)
# ('Training epoch 30, cost ', 496.66687)
# ('Training epoch 31, cost ', 496.62515)
# ('Training epoch 32, cost ', 496.54575)
# ('Training epoch 33, cost ', 496.50977)
# ('Training epoch 34, cost ', 496.45728)
# ('Training epoch 35, cost ', 496.39407)
# ('Training epoch 36, cost ', 496.33228)
# ('Training epoch 37, cost ', 496.3172)
# ('Training epoch 38, cost ', 496.26816)
# ('Training epoch 39, cost ', 496.21576)
# ('Training epoch 40, cost ', 496.16696)
# ('Training epoch 41, cost ', 496.13715)
# ('Training epoch 42, cost ', 496.10416)
# ('Training epoch 43, cost ', 496.08075)
# ('Training epoch 44, cost ', 496.03482)
# ('Training epoch 45, cost ', 496.00378)
# ('Training epoch 46, cost ', 495.96399)
# ('Training epoch 47, cost ', 495.94354)
# ('Training epoch 48, cost ', 495.90366)
# ('Training epoch 49, cost ', 495.87192)
# ('Training epoch 50, cost ', 495.85126)
# ('Training epoch 51, cost ', 495.80798)
# ('Training epoch 52, cost ', 495.77698)
# ('Training epoch 53, cost ', 495.77103)
# ('Training epoch 54, cost ', 495.71481)
# ('Training epoch 55, cost ', 495.7229)
# ('Training epoch 56, cost ', 495.65451)
# ('Training epoch 57, cost ', 495.65729)
# ('Training epoch 58, cost ', 495.61261)
# ('Training epoch 59, cost ', 495.60117)
# ('Training epoch 60, cost ', 495.56226)
# ('Training epoch 61, cost ', 495.54581)
# ('Training epoch 62, cost ', 495.51126)
# ('Training epoch 63, cost ', 495.48801)
# ('Training epoch 64, cost ', 495.49088)
# ('Training epoch 65, cost ', 495.44052)
# ('Training epoch 66, cost ', 495.4187)
# ('Training epoch 67, cost ', 495.4061)
# ('Training epoch 68, cost ', 495.38943)
# ('Training epoch 69, cost ', 495.35764)
# ('Training epoch 70, cost ', 495.3493)
# ('Training epoch 71, cost ', 495.31958)
# ('Training epoch 72, cost ', 495.28925)
# ('Training epoch 73, cost ', 495.258)
# ('Training epoch 74, cost ', 495.25977)
# ('Training epoch 75, cost ', 495.24753)
# ('Training epoch 76, cost ', 495.21976)
# ('Training epoch 77, cost ', 495.20245)
# ('Training epoch 78, cost ', 495.19058)
# ('Training epoch 79, cost ', 495.15692)
# ('Training epoch 80, cost ', 495.14627)
# ('Training epoch 81, cost ', 495.14203)
# ('Training epoch 82, cost ', 495.11179)
# ('Training epoch 83, cost ', 495.10556)
# ('Training epoch 84, cost ', 495.07138)
# ('Training epoch 85, cost ', 495.05072)
# ('Training epoch 86, cost ', 495.05566)
# ('Training epoch 87, cost ', 495.03561)
# ('Training epoch 88, cost ', 495.03424)
# ('Training epoch 89, cost ', 494.99716)
# ('Training epoch 90, cost ', 494.98065)
# ('Training epoch 91, cost ', 494.97562)
# ('Training epoch 92, cost ', 494.94174)
# ('Training epoch 93, cost ', 494.93137)
# ('Training epoch 94, cost ', 494.91693)
# ('Training epoch 95, cost ', 494.90933)
# ('Training epoch 96, cost ', 494.90179)
# ('Training epoch 97, cost ', 494.88522)
# ('Training epoch 98, cost ', 494.85361)
# ('Training epoch 99, cost ', 494.84769)
# ('Training epoch 100, cost ', 494.84744)
# ('Training epoch 101, cost ', 494.82263)
# ('Training epoch 102, cost ', 494.81357)
# ('Training epoch 103, cost ', 494.80099)
# ('Training epoch 104, cost ', 494.7782)
# ('Training epoch 105, cost ', 494.77945)
# ('Training epoch 106, cost ', 494.75543)
# ('Training epoch 107, cost ', 494.72794)
# ('Training epoch 108, cost ', 494.73883)
# ('Training epoch 109, cost ', 494.7132)
# ('Training epoch 110, cost ', 494.69461)
# ('Training epoch 111, cost ', 494.68198)
# ('Training epoch 112, cost ', 494.66177)
# ('Training epoch 113, cost ', 494.66306)
# ('Training epoch 114, cost ', 494.66418)
# ('Training epoch 115, cost ', 494.6376)
# ('Training epoch 116, cost ', 494.62881)
# ('Training epoch 117, cost ', 494.61597)
# ('Training epoch 118, cost ', 494.59976)
# ('Training epoch 119, cost ', 494.59885)
# ('Training epoch 120, cost ', 494.58316)
# ('Training epoch 121, cost ', 494.5632)
# ('Training epoch 122, cost ', 494.55496)
# ('Training epoch 123, cost ', 494.56339)
# ('Training epoch 124, cost ', 494.52719)
# ('Training epoch 125, cost ', 494.50836)
# ('Training epoch 126, cost ', 494.4935)
# ('Training epoch 127, cost ', 494.52252)
# ('Training epoch 128, cost ', 494.48547)
# ('Training epoch 129, cost ', 494.47128)
# ('Training epoch 130, cost ', 494.4639)
# ('Training epoch 131, cost ', 494.44501)
# ('Training epoch 132, cost ', 494.45068)
# ('Training epoch 133, cost ', 494.42731)
# ('Training epoch 134, cost ', 494.43484)
# ('Training epoch 135, cost ', 494.41187)
# ('Training epoch 136, cost ', 494.40152)
# ('Training epoch 137, cost ', 494.40445)
# ('Training epoch 138, cost ', 494.37793)
# ('Training epoch 139, cost ', 494.39102)
# ('Training epoch 140, cost ', 494.37482)
# ('Training epoch 141, cost ', 494.3537)
# ('Training epoch 142, cost ', 494.35461)
# ('Training epoch 143, cost ', 494.34253)
# ('Training epoch 144, cost ', 494.32822)
# ('Training epoch 145, cost ', 494.31979)
# ('Training epoch 146, cost ', 494.31235)
# ('Training epoch 147, cost ', 494.30099)
# ('Training epoch 148, cost ', 494.30283)
# ('Training epoch 149, cost ', 494.29202)
# ('Training epoch 150, cost ', 494.26968)
# ('Training epoch 151, cost ', 494.27972)
# ('Training epoch 152, cost ', 494.26376)
# ('Training epoch 153, cost ', 494.25436)
# ('Training epoch 154, cost ', 494.23428)
# ('Training epoch 155, cost ', 494.23795)
# ('Training epoch 156, cost ', 494.23123)
# ('Training epoch 157, cost ', 494.21753)
# ('Training epoch 158, cost ', 494.20718)
# ('Training epoch 159, cost ', 494.21481)
# ('Training epoch 160, cost ', 494.18271)
# ('Training epoch 161, cost ', 494.18634)
# ('Training epoch 162, cost ', 494.17609)
# ('Training epoch 163, cost ', 494.18256)
# ('Training epoch 164, cost ', 494.17508)
# ('Training epoch 165, cost ', 494.15778)
# ('Training epoch 166, cost ', 494.15088)
# ('Training epoch 167, cost ', 494.15237)
# ('Training epoch 168, cost ', 494.14264)
# ('Training epoch 169, cost ', 494.13715)
# ('Training epoch 170, cost ', 494.12906)
# ('Training epoch 171, cost ', 494.12003)
# ('Training epoch 172, cost ', 494.11908)
# ('Training epoch 173, cost ', 494.09448)
# ('Training epoch 174, cost ', 494.08508)
# ('Training epoch 175, cost ', 494.09009)
# ('Training epoch 176, cost ', 494.07529)
# ('Training epoch 177, cost ', 494.09177)
# ('Training epoch 178, cost ', 494.06393)
# ('Training epoch 179, cost ', 494.06656)
# ('Training epoch 180, cost ', 494.05676)
# ('Training epoch 181, cost ', 494.04041)
# ('Training epoch 182, cost ', 494.03827)
# ('Training epoch 183, cost ', 494.03659)
# ('Training epoch 184, cost ', 494.02573)
# ('Training epoch 185, cost ', 494.01712)
# ('Training epoch 186, cost ', 494.0094)
# ('Training epoch 187, cost ', 494.01089)
# ('Training epoch 188, cost ', 493.99426)
# ('Training epoch 189, cost ', 494.01758)
# ('Training epoch 190, cost ', 493.98575)
# ('Training epoch 191, cost ', 493.99637)
# ('Training epoch 192, cost ', 493.9783)
# ('Training epoch 193, cost ', 493.99368)
# ('Training epoch 194, cost ', 493.9632)
# ('Training epoch 195, cost ', 493.97104)
# ('Training epoch 196, cost ', 493.9646)
# ('Training epoch 197, cost ', 493.95215)
# ('Training epoch 198, cost ', 493.93903)
# ('Training epoch 199, cost ', 493.94165)
# The 0.100000 corruption dAutoenconder finished

# %%
# change correpution level to 0.35
corruptionL=0.35

############
# train dAutoencoder                 
############
dfLLdata = funcs.test_dA(learning_rate, training_epochs, corruptionL, batch_size, output_folder)

############
### plotting or cost
### the cost we minimize during training is the negative log likelihood of
############
x = dfLLdata['iter'].values
y = dfLLdata['LL_iter'].values
plt.figure()
plt.plot(x, y, 'bo--')
plt.xlabel('epoch', fontsize=14)
plt.ylabel('dA Cost', fontsize=14)
plt.title('MLP: learning_rate = '+str(learning_rate)+' batch_size = '+str(batch_size), fontsize=14)
# Out:
# ... loading data
#         lesion_id nmenh_dist nmenh_intenh
# count        8884       8884         8884
# unique        500          6            4
# top           576        N/A          N/A
# freq           25       4150         8182
# [(u'Ductal', 0), (u'Focal', 1), (u'Linear', 2), (u'N/A', 3), (u'Regional', 4), (u'Segmental', 5)]
# Removing incomplete patches...
# [505, 951, 1467, 1818, 2040, 3220, 3789, 4112, 4924, 5068, 6067, 8838]
# Number of patches: 5325 train, 1714 valid, 1833 test
# ('Training epoch 0, cost ', 526.85376)
# ('Training epoch 1, cost ', 511.85251)
# ('Training epoch 2, cost ', 506.99344)
# ('Training epoch 3, cost ', 503.95801)
# ('Training epoch 4, cost ', 501.90045)
# ('Training epoch 5, cost ', 500.50665)
# ('Training epoch 6, cost ', 499.48956)
# ('Training epoch 7, cost ', 498.80167)
# ('Training epoch 8, cost ', 498.2579)
# ('Training epoch 9, cost ', 497.81223)
# ('Training epoch 10, cost ', 497.45923)
# ('Training epoch 11, cost ', 497.17346)
# ('Training epoch 12, cost ', 496.85269)
# ('Training epoch 13, cost ', 496.61673)
# ('Training epoch 14, cost ', 496.46637)
# ('Training epoch 15, cost ', 496.26343)
# ('Training epoch 16, cost ', 496.10904)
# ('Training epoch 17, cost ', 495.95596)
# ('Training epoch 18, cost ', 495.83545)
# ('Training epoch 19, cost ', 495.75107)
# ('Training epoch 20, cost ', 495.61182)
# ('Training epoch 21, cost ', 495.53711)
# ('Training epoch 22, cost ', 495.37708)
# ('Training epoch 23, cost ', 495.30267)
# ('Training epoch 24, cost ', 495.21863)
# ('Training epoch 25, cost ', 495.14163)
# ('Training epoch 26, cost ', 495.05389)
# ('Training epoch 27, cost ', 494.96957)
# ('Training epoch 28, cost ', 494.93839)
# ('Training epoch 29, cost ', 494.88382)
# ('Training epoch 30, cost ', 494.79636)
# ('Training epoch 31, cost ', 494.76166)
# ('Training epoch 32, cost ', 494.67007)
# ('Training epoch 33, cost ', 494.62201)
# ('Training epoch 34, cost ', 494.54208)
# ('Training epoch 35, cost ', 494.52423)
# ('Training epoch 36, cost ', 494.46463)
# ('Training epoch 37, cost ', 494.42706)
# ('Training epoch 38, cost ', 494.40674)
# ('Training epoch 39, cost ', 494.32541)
# ('Training epoch 40, cost ', 494.28607)
# ('Training epoch 41, cost ', 494.26971)
# ('Training epoch 42, cost ', 494.22662)
# ('Training epoch 43, cost ', 494.15945)
# ('Training epoch 44, cost ', 494.18271)
# ('Training epoch 45, cost ', 494.1257)
# ('Training epoch 46, cost ', 494.10956)
# ('Training epoch 47, cost ', 494.09204)
# ('Training epoch 48, cost ', 494.06049)
# ('Training epoch 49, cost ', 494.00558)
# ('Training epoch 50, cost ', 493.96497)
# ('Training epoch 51, cost ', 493.9299)
# ('Training epoch 52, cost ', 493.95572)
# ('Training epoch 53, cost ', 493.91037)
# ('Training epoch 54, cost ', 493.90552)
# ('Training epoch 55, cost ', 493.89011)
# ('Training epoch 56, cost ', 493.80371)
# ('Training epoch 57, cost ', 493.8439)
# ('Training epoch 58, cost ', 493.7709)
# ('Training epoch 59, cost ', 493.76654)
# ('Training epoch 60, cost ', 493.75024)
# ('Training epoch 61, cost ', 493.78812)
# ('Training epoch 62, cost ', 493.69876)
# ('Training epoch 63, cost ', 493.71045)
# ('Training epoch 64, cost ', 493.6597)
# ('Training epoch 65, cost ', 493.63034)
# ('Training epoch 66, cost ', 493.63373)
# ('Training epoch 67, cost ', 493.59909)
# ('Training epoch 68, cost ', 493.60593)
# ('Training epoch 69, cost ', 493.56631)
# ('Training epoch 70, cost ', 493.60895)
# ('Training epoch 71, cost ', 493.57373)
# ('Training epoch 72, cost ', 493.54688)
# ('Training epoch 73, cost ', 493.54166)
# ('Training epoch 74, cost ', 493.54575)
# ('Training epoch 75, cost ', 493.46442)
# ('Training epoch 76, cost ', 493.47299)
# ('Training epoch 77, cost ', 493.45313)
# ('Training epoch 78, cost ', 493.41284)
# ('Training epoch 79, cost ', 493.47388)
# ('Training epoch 80, cost ', 493.43951)
# ('Training epoch 81, cost ', 493.40106)
# ('Training epoch 82, cost ', 493.38678)
# ('Training epoch 83, cost ', 493.37256)
# ('Training epoch 84, cost ', 493.35977)
# ('Training epoch 85, cost ', 493.39209)
# ('Training epoch 86, cost ', 493.37161)
# ('Training epoch 87, cost ', 493.3194)
# ('Training epoch 88, cost ', 493.34152)
# ('Training epoch 89, cost ', 493.29105)
# ('Training epoch 90, cost ', 493.28513)
# ('Training epoch 91, cost ', 493.2861)
# ('Training epoch 92, cost ', 493.30258)
# ('Training epoch 93, cost ', 493.23694)
# ('Training epoch 94, cost ', 493.25348)
# ('Training epoch 95, cost ', 493.23807)
# ('Training epoch 96, cost ', 493.23917)
# ('Training epoch 97, cost ', 493.23685)
# ('Training epoch 98, cost ', 493.17056)
# ('Training epoch 99, cost ', 493.16501)
# ('Training epoch 100, cost ', 493.16077)
# ('Training epoch 101, cost ', 493.20746)
# ('Training epoch 102, cost ', 493.16595)
# ('Training epoch 103, cost ', 493.17224)
# ('Training epoch 104, cost ', 493.14603)
# ('Training epoch 105, cost ', 493.1434)
# ('Training epoch 106, cost ', 493.18835)
# ('Training epoch 107, cost ', 493.19745)
# ('Training epoch 108, cost ', 493.09818)
# ('Training epoch 109, cost ', 493.10223)
# ('Training epoch 110, cost ', 493.1398)
# ('Training epoch 111, cost ', 493.10687)
# ('Training epoch 112, cost ', 493.10226)
# ('Training epoch 113, cost ', 493.06912)
# ('Training epoch 114, cost ', 493.07822)
# ('Training epoch 115, cost ', 493.02744)
# ('Training epoch 116, cost ', 493.04996)
# ('Training epoch 117, cost ', 493.04993)
# ('Training epoch 118, cost ', 493.01813)
# ('Training epoch 119, cost ', 493.00296)
# ('Training epoch 120, cost ', 492.99924)
# ('Training epoch 121, cost ', 493.02234)
# ('Training epoch 122, cost ', 492.99695)
# ('Training epoch 123, cost ', 493.01926)
# ('Training epoch 124, cost ', 492.95303)
# ('Training epoch 125, cost ', 492.97003)
# ('Training epoch 126, cost ', 492.98132)
# ('Training epoch 127, cost ', 492.9538)
# ('Training epoch 128, cost ', 492.95261)
# ('Training epoch 129, cost ', 492.94873)
# ('Training epoch 130, cost ', 492.97046)
# ('Training epoch 131, cost ', 492.96484)
# ('Training epoch 132, cost ', 492.91989)
# ('Training epoch 133, cost ', 492.97174)
# ('Training epoch 134, cost ', 492.95334)
# ('Training epoch 135, cost ', 492.93539)
# ('Training epoch 136, cost ', 492.9389)
# ('Training epoch 137, cost ', 492.92484)
# ('Training epoch 138, cost ', 492.89917)
# ('Training epoch 139, cost ', 492.89642)
# ('Training epoch 140, cost ', 492.91589)
# ('Training epoch 141, cost ', 492.86044)
# ('Training epoch 142, cost ', 492.89429)
# ('Training epoch 143, cost ', 492.83545)
# ('Training epoch 144, cost ', 492.89349)
# ('Training epoch 145, cost ', 492.81894)
# ('Training epoch 146, cost ', 492.87369)
# ('Training epoch 147, cost ', 492.82635)
# ('Training epoch 148, cost ', 492.83603)
# ('Training epoch 149, cost ', 492.84763)
# ('Training epoch 150, cost ', 492.81326)
# ('Training epoch 151, cost ', 492.80734)
# ('Training epoch 152, cost ', 492.82672)
# ('Training epoch 153, cost ', 492.86157)
# ('Training epoch 154, cost ', 492.81265)
# ('Training epoch 155, cost ', 492.82813)
# ('Training epoch 156, cost ', 492.79889)
# ('Training epoch 157, cost ', 492.79819)
# ('Training epoch 158, cost ', 492.7529)
# ('Training epoch 159, cost ', 492.80344)
# ('Training epoch 160, cost ', 492.78522)
# ('Training epoch 161, cost ', 492.7749)
# ('Training epoch 162, cost ', 492.77441)
# ('Training epoch 163, cost ', 492.79846)
# ('Training epoch 164, cost ', 492.76044)
# ('Training epoch 165, cost ', 492.76587)
# ('Training epoch 166, cost ', 492.75726)
# ('Training epoch 167, cost ', 492.79724)
# ('Training epoch 168, cost ', 492.77808)
# ('Training epoch 169, cost ', 492.78314)
# ('Training epoch 170, cost ', 492.72052)
# ('Training epoch 171, cost ', 492.74835)
# ('Training epoch 172, cost ', 492.75281)
# ('Training epoch 173, cost ', 492.77921)
# ('Training epoch 174, cost ', 492.72559)
# ('Training epoch 175, cost ', 492.7536)
# ('Training epoch 176, cost ', 492.74557)
# ('Training epoch 177, cost ', 492.7446)
# ('Training epoch 178, cost ', 492.68784)
# ('Training epoch 179, cost ', 492.73123)
# ('Training epoch 180, cost ', 492.69281)
# ('Training epoch 181, cost ', 492.67975)
# ('Training epoch 182, cost ', 492.71262)
# ('Training epoch 183, cost ', 492.69928)
# ('Training epoch 184, cost ', 492.68594)
# ('Training epoch 185, cost ', 492.65213)
# ('Training epoch 186, cost ', 492.70099)
# ('Training epoch 187, cost ', 492.66434)
# ('Training epoch 188, cost ', 492.6741)
# ('Training epoch 189, cost ', 492.69629)
# ('Training epoch 190, cost ', 492.68027)
# ('Training epoch 191, cost ', 492.69061)
# ('Training epoch 192, cost ', 492.67993)
# ('Training epoch 193, cost ', 492.6528)
# ('Training epoch 194, cost ', 492.64938)
# ('Training epoch 195, cost ', 492.64731)
# ('Training epoch 196, cost ', 492.66022)
# ('Training epoch 197, cost ', 492.60226)
# ('Training epoch 198, cost ', 492.62701)
# ('Training epoch 199, cost ', 492.66455)
# The 0.350000 corruption dAutoenconder finished

# %%
# change correpution level to 0.45
corruptionL=0.45

############
# train dAutoencoder                 
############
dfLLdata = funcs.test_dA(learning_rate, training_epochs, corruptionL, batch_size, output_folder)

############
### plotting or cost
### the cost we minimize during training is the negative log likelihood of
############
x = dfLLdata['iter'].values
y = dfLLdata['LL_iter'].values
plt.figure()
plt.plot(x, y, 'bo--')
plt.xlabel('epoch', fontsize=14)
plt.ylabel('dA Cost', fontsize=14)
plt.title('MLP: learning_rate = '+str(learning_rate)+' batch_size = '+str(batch_size), fontsize=14)
# Out:
# ... loading data
#         lesion_id nmenh_dist nmenh_intenh
# count        8884       8884         8884
# unique        500          6            4
# top           576        N/A          N/A
# freq           25       4150         8182
# [(u'Ductal', 0), (u'Focal', 1), (u'Linear', 2), (u'N/A', 3), (u'Regional', 4), (u'Segmental', 5)]
# Removing incomplete patches...
# [505, 951, 1467, 1818, 2040, 3220, 3789, 4112, 4924, 5068, 6067, 8838]
# Number of patches: 5253 train, 1800 valid, 1819 test
# ('Training epoch 0, cost ', 526.82172)
# ('Training epoch 1, cost ', 512.9306)
# ('Training epoch 2, cost ', 508.66174)
# ('Training epoch 3, cost ', 505.922)
# ('Training epoch 4, cost ', 504.08667)
# ('Training epoch 5, cost ', 502.76617)
# ('Training epoch 6, cost ', 501.79694)
# ('Training epoch 7, cost ', 501.06512)
# ('Training epoch 8, cost ', 500.50134)
# ('Training epoch 9, cost ', 500.04266)
# ('Training epoch 10, cost ', 499.68268)
# ('Training epoch 11, cost ', 499.33139)
# ('Training epoch 12, cost ', 499.06454)
# ('Training epoch 13, cost ', 498.80383)
# ('Training epoch 14, cost ', 498.58301)
# ('Training epoch 15, cost ', 498.39713)
# ('Training epoch 16, cost ', 498.21426)
# ('Training epoch 17, cost ', 498.05389)
# ('Training epoch 18, cost ', 497.91199)
# ('Training epoch 19, cost ', 497.8114)
# ('Training epoch 20, cost ', 497.6843)
# ('Training epoch 21, cost ', 497.57846)
# ('Training epoch 22, cost ', 497.43137)
# ('Training epoch 23, cost ', 497.34216)
# ('Training epoch 24, cost ', 497.27084)
# ('Training epoch 25, cost ', 497.18988)
# ('Training epoch 26, cost ', 497.09921)
# ('Training epoch 27, cost ', 496.99258)
# ('Training epoch 28, cost ', 496.91516)
# ('Training epoch 29, cost ', 496.88647)
# ('Training epoch 30, cost ', 496.82941)
# ('Training epoch 31, cost ', 496.76715)
# ('Training epoch 32, cost ', 496.71582)
# ('Training epoch 33, cost ', 496.63443)
# ('Training epoch 34, cost ', 496.61819)
# ('Training epoch 35, cost ', 496.55246)
# ('Training epoch 36, cost ', 496.53741)
# ('Training epoch 37, cost ', 496.48752)
# ('Training epoch 38, cost ', 496.4454)
# ('Training epoch 39, cost ', 496.37689)
# ('Training epoch 40, cost ', 496.34482)
# ('Training epoch 41, cost ', 496.3172)
# ('Training epoch 42, cost ', 496.25705)
# ('Training epoch 43, cost ', 496.26038)
# ('Training epoch 44, cost ', 496.23157)
# ('Training epoch 45, cost ', 496.16861)
# ('Training epoch 46, cost ', 496.16418)
# ('Training epoch 47, cost ', 496.12451)
# ('Training epoch 48, cost ', 496.10486)
# ('Training epoch 49, cost ', 496.06897)
# ('Training epoch 50, cost ', 496.1001)
# ('Training epoch 51, cost ', 496.0087)
# ('Training epoch 52, cost ', 496.00229)
# ('Training epoch 53, cost ', 495.94363)
# ('Training epoch 54, cost ', 495.94479)
# ('Training epoch 55, cost ', 495.92621)
# ('Training epoch 56, cost ', 495.94846)
# ('Training epoch 57, cost ', 495.89667)
# ('Training epoch 58, cost ', 495.85672)
# ('Training epoch 59, cost ', 495.82034)
# ('Training epoch 60, cost ', 495.81122)
# ('Training epoch 61, cost ', 495.81522)
# ('Training epoch 62, cost ', 495.79807)
# ('Training epoch 63, cost ', 495.79599)
# ('Training epoch 64, cost ', 495.76343)
# ('Training epoch 65, cost ', 495.73666)
# ('Training epoch 66, cost ', 495.70911)
# ('Training epoch 67, cost ', 495.67737)
# ('Training epoch 68, cost ', 495.6828)
# ('Training epoch 69, cost ', 495.72211)
# ('Training epoch 70, cost ', 495.67926)
# ('Training epoch 71, cost ', 495.59286)
# ('Training epoch 72, cost ', 495.67688)
# ('Training epoch 73, cost ', 495.60852)
# ('Training epoch 74, cost ', 495.63437)
# ('Training epoch 75, cost ', 495.54047)
# ('Training epoch 76, cost ', 495.56207)
# ('Training epoch 77, cost ', 495.56903)
# ('Training epoch 78, cost ', 495.5813)
# ('Training epoch 79, cost ', 495.54074)
# ('Training epoch 80, cost ', 495.56464)
# ('Training epoch 81, cost ', 495.51941)
# ('Training epoch 82, cost ', 495.47058)
# ('Training epoch 83, cost ', 495.49487)
# ('Training epoch 84, cost ', 495.43265)
# ('Training epoch 85, cost ', 495.44031)
# ('Training epoch 86, cost ', 495.42578)
# ('Training epoch 87, cost ', 495.47968)
# ('Training epoch 88, cost ', 495.41013)
# ('Training epoch 89, cost ', 495.41031)
# ('Training epoch 90, cost ', 495.4007)
# ('Training epoch 91, cost ', 495.38391)
# ('Training epoch 92, cost ', 495.3313)
# ('Training epoch 93, cost ', 495.33835)
# ('Training epoch 94, cost ', 495.36673)
# ('Training epoch 95, cost ', 495.33127)
# ('Training epoch 96, cost ', 495.39508)
# ('Training epoch 97, cost ', 495.36206)
# ('Training epoch 98, cost ', 495.3233)
# ('Training epoch 99, cost ', 495.32016)
# ('Training epoch 100, cost ', 495.30484)
# ('Training epoch 101, cost ', 495.2597)
# ('Training epoch 102, cost ', 495.27338)
# ('Training epoch 103, cost ', 495.30493)
# ('Training epoch 104, cost ', 495.23969)
# ('Training epoch 105, cost ', 495.30417)
# ('Training epoch 106, cost ', 495.27438)
# ('Training epoch 107, cost ', 495.23868)
# ('Training epoch 108, cost ', 495.23935)
# ('Training epoch 109, cost ', 495.22458)
# ('Training epoch 110, cost ', 495.24542)
# ('Training epoch 111, cost ', 495.23059)
# ('Training epoch 112, cost ', 495.18164)
# ('Training epoch 113, cost ', 495.14355)
# ('Training epoch 114, cost ', 495.21124)
# ('Training epoch 115, cost ', 495.20383)
# ('Training epoch 116, cost ', 495.20279)
# ('Training epoch 117, cost ', 495.18079)
# ('Training epoch 118, cost ', 495.16632)
# ('Training epoch 119, cost ', 495.12723)
# ('Training epoch 120, cost ', 495.16388)
# ('Training epoch 121, cost ', 495.1507)
# ('Training epoch 122, cost ', 495.13385)
# ('Training epoch 123, cost ', 495.12866)
# ('Training epoch 124, cost ', 495.10355)
# ('Training epoch 125, cost ', 495.13446)
# ('Training epoch 126, cost ', 495.1091)
# ('Training epoch 127, cost ', 495.14072)
# ('Training epoch 128, cost ', 495.15485)
# ('Training epoch 129, cost ', 495.11234)
# ('Training epoch 130, cost ', 495.13458)
# ('Training epoch 131, cost ', 495.05637)
# ('Training epoch 132, cost ', 495.07388)
# ('Training epoch 133, cost ', 495.07477)
# ('Training epoch 134, cost ', 495.06845)
# ('Training epoch 135, cost ', 495.10919)
# ('Training epoch 136, cost ', 495.12872)
# ('Training epoch 137, cost ', 495.1109)
# ('Training epoch 138, cost ', 495.09131)
# ('Training epoch 139, cost ', 495.08896)
# ('Training epoch 140, cost ', 495.12552)
# ('Training epoch 141, cost ', 495.01648)
# ('Training epoch 142, cost ', 495.0694)
# ('Training epoch 143, cost ', 495.08484)
# ('Training epoch 144, cost ', 495.04099)
# ('Training epoch 145, cost ', 495.07617)
# ('Training epoch 146, cost ', 495.06418)
# ('Training epoch 147, cost ', 495.00104)
# ('Training epoch 148, cost ', 494.98895)
# ('Training epoch 149, cost ', 495.01257)
# ('Training epoch 150, cost ', 495.0061)
# ('Training epoch 151, cost ', 495.04105)
# ('Training epoch 152, cost ', 495.09781)
# ('Training epoch 153, cost ', 494.9744)
# ('Training epoch 154, cost ', 494.96796)
# ('Training epoch 155, cost ', 494.96121)
# ('Training epoch 156, cost ', 494.98105)
# ('Training epoch 157, cost ', 494.94498)
# ('Training epoch 158, cost ', 494.94525)
# ('Training epoch 159, cost ', 494.98306)
# ('Training epoch 160, cost ', 494.9263)
# ('Training epoch 161, cost ', 494.996)
# ('Training epoch 162, cost ', 494.98599)
# ('Training epoch 163, cost ', 494.96677)
# ('Training epoch 164, cost ', 494.97977)
# ('Training epoch 165, cost ', 494.94849)
# ('Training epoch 166, cost ', 494.95706)
# ('Training epoch 167, cost ', 494.99191)
# ('Training epoch 168, cost ', 494.90128)
# ('Training epoch 169, cost ', 494.91223)
# ('Training epoch 170, cost ', 494.90009)
# ('Training epoch 171, cost ', 494.88608)
# ('Training epoch 172, cost ', 494.92892)
# ('Training epoch 173, cost ', 494.87296)
# ('Training epoch 174, cost ', 494.88947)
# ('Training epoch 175, cost ', 494.92337)
# ('Training epoch 176, cost ', 494.92679)
# ('Training epoch 177, cost ', 494.84839)
# ('Training epoch 178, cost ', 494.90985)
# ('Training epoch 179, cost ', 494.88272)
# ('Training epoch 180, cost ', 494.89523)
# ('Training epoch 181, cost ', 494.89548)
# ('Training epoch 182, cost ', 494.82919)
# ('Training epoch 183, cost ', 494.83548)
# ('Training epoch 184, cost ', 494.853)
# ('Training epoch 185, cost ', 494.8811)
# ('Training epoch 186, cost ', 494.84201)
# ('Training epoch 187, cost ', 494.78067)
# ('Training epoch 188, cost ', 494.86377)
# ('Training epoch 189, cost ', 494.89728)
# ('Training epoch 190, cost ', 494.84836)
# ('Training epoch 191, cost ', 494.85928)
# ('Training epoch 192, cost ', 494.83301)
# ('Training epoch 193, cost ', 494.89548)
# ('Training epoch 194, cost ', 494.86014)
# ('Training epoch 195, cost ', 494.8118)
# ('Training epoch 196, cost ', 494.82083)
# ('Training epoch 197, cost ', 494.81332)
# ('Training epoch 198, cost ', 494.8223)
# ('Training epoch 199, cost ', 494.80399)
# The 0.450000 corruption dAutoenconder finished
